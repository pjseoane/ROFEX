# %%
from Classes import cSetUp as st

# %%
usr1=st.cROFEXSuscription(["DoDic18"])
# Out:
# login() OK ---> +RvBniprDdFa/SMPeq714KDY51GUB9Rxp37cMsfERac=
# Sent Suscription msg DoDic18
# Receiving...
# En goRobot***-> 1 -- DoDic18 --> 38.492 / 38.533      100 / 10

# %%
usr1.instrumentos()
# Out:
# {'status': 'OK',
#  'instruments': [{'instrumentId': {'marketId': 'ROFX',
#     'symbol': 'MATBA - ELEC - SOJ.ROS/MAY19 234 P'},
#    'cficode': 'OPAFXS'},
#   {'instrumentId': {'marketId': 'ROFX',
#     'symbol': 'MATBA - ELEC - MAI.MIN/DIC18 168 P'},
#    'cficode': 'OPAFXS'},
#   {'instrumentId': {'marketId': 'ROFX', 'symbol': 'AY24Mar19'},
#    'cficode': 'FXXXSX'},
#   {'instrumentId': {'marketId': 'ROFX', 'symbol': 'CRNNov18 132p'},
#    'cficode': 'OPAFXS'},
#   {'instrumentId': {'marketId': 'ROFX',
#     'symbol': 'MATBA - ELEC - SOJ.ROS/NOV18_MAY19'},
#    'cficode': 'FXXXXX'},
#   {'instrumentId': {'marketId': 'ROFX',
#     'symbol': 'MATBA - ELEC - NOV.D/FEB19'},
#    'cficode': 'FXXXSX'},
#   {'instrumentId': {'marketId': 'ROFX', 'symbol': 'DOSep19A'},
#    'cficode': 'FXXXSX'},
#   {'instrumentId': {'marketId': 'ROFX', 'symbol': 'DONov18'},
#    'cficode': 'FXXXSX'},
#   {'instrumentId': {'marketId': 'ROFX',
#     'symbol': 'MATBA - ELEC - SOJ.MIN/MAY19 266 C'},
# ...
